# %% [raw]
# ---
# description: Project about webscrapping Pokemon data from the internet and building
#   and app to be able to quickly obtain information from the data to ease competitive
#   team building.
# output-file: index.html
# title: pokedata
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## How to use

# %% [markdown]
# First you will need to obtain the pokemon stats. To do so, run notebook `00_00_getting_stats.ipynb`.
